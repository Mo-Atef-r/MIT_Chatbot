# %% [markdown]
# ## Web Scraping

# %%
import requests
from bs4 import BeautifulSoup, Tag, NavigableString
import pandas as pd
from IPython.display import display

# %%
url = 'https://catalog.mit.edu/subjects/6/'
page = requests.get(url)
doc = BeautifulSoup(page.text, 'html.parser')
#print(doc.prettify())

# %%
main= doc.find("div", id="sc_sccoursedescs")

# %%
table =[]
sectionhead= None

for tag in list(main.children):
    if not isinstance(tag, Tag):
        continue
        
    if "sectionhead" in tag['class'] :
        sectionhead= tag.string
        
    elif "courseblock" in tag['class']:
        title= prereq= terms= hours= optional= desc= instructor= None
        for child in tag.children:
            if not isinstance(child, Tag):
                    continue
            #print("child's class: ", child['class'])
            
            if "courseblocktitle" in child['class']:
                title= child.find("strong").get_text(strip=True, separator=' ')
                
            elif "courseblockextra" in child['class'] :
                prereq= child.find(class_="courseblockprereq").get_text(strip=True, separator=' ')
                
                terms= child.find(class_="courseblockterms").get_text(strip=True, separator=' ')
                hours= child.find(class_="courseblockhours").get_text(strip=True, separator=' ')
                optional= child.find(class_="courseblockoptional")
                if optional:
                    optional = optional.get_text(strip=True, separator=' ')
                
            elif "courseblockdesc" in child['class']:
                desc= child.get_text(strip=True, separator=' ')
                
            elif "courseblockinstructors" in child['class']:
                
                instructor= child.find("i").get_text(strip=True, separator=' ')
                
        table.append({
        "title": title, "prereq":prereq,
        "terms":terms, "hours":hours,"optional":optional,
        "description":desc, "instructor": instructor,
        "section_head": sectionhead})

# %%
df=pd.DataFrame(table)
display(df.head())
display(df.describe())
# Out:
#                                                title  \
# 0  6.100A Introduction to Computer Science Progra...
# 1  6.100B Introduction to Computational Thinking ...
# 2  6.100L Introduction to Computer Science and Pr...
# 3                 6.1010 Fundamentals of Programming
# 4                       6.1020 Software Construction
#
#                                        prereq  \
# 0                                Prereq: None
# 1  Prereq: 6.100A or permission of instructor
# 2                                Prereq: None
# 3                              Prereq: 6.100A
# 4                              Prereq: 6.1010
#
#                                    terms                       hours  \
# 0   U (Fall, Spring; first half of term)                 2-0-4 units
# 1  U (Fall, Spring; second half of term)                 2-0-4 units
# 2                       U (Fall, Spring)                 2-0-4 units
# 3                       U (Fall, Spring)  2-4-6 units. Institute LAB
# 4                             U (Spring)                3-0-12 units
#
#                                             optional  \
# 0          Credit cannot also be received for 6.100L
# 1  Credit cannot also be received for 9.C20[J] , ...
# 2          Credit cannot also be received for 6.100A
# 3                                               None
# 4                                               None
#
#                                          description  \
# 0  Introduction to computer science and programmi...
# 1  Provides an introduction to using computation ...
# 2  Introduction to computer science and programmi...
# 3  Introduces fundamental concepts of programming...
# 4  Introduces fundamental principles and techniqu...
#
#                                         instructor  \
# 0                                          A. Bell
# 1                            A. Bell, J. V. Guttag
# 2                            A. Bell, J. V. Guttag
# 3  D. S. Boning, A. Chlipala, S. Devadas, A. Hartz
# 4                         M. Goldman, R. C. Miller
#
#                          section_head
# 0  Programming & Software Engineering
# 1  Programming & Software Engineering
# 2  Programming & Software Engineering
# 3  Programming & Software Engineering
# 4  Programming & Software Engineering
#                                                     title        prereq  \
# count                                                 406           406
# unique                                                406           179
# top     6.C85[J] Interactive Data Visualization and So...  Prereq: None
# freq                                                    1            95
#
#            terms        hours                     optional  \
# count        406          406                          143
# unique        40           70                           12
# top     G (Fall)  3-0-9 units  Can be repeated for credit.
# freq          56          126                          130
#
#                                               description          instructor  \
# count                                                 406                 406
# unique                                                286                 219
# top     Covers subject matter not offered in the regul...  Consult Department
# freq                                                   76                  95
#
#             section_head
# count                406
# unique                32
# top     Special Subjects
# freq                 108

# %%
df[df['prereq'].str[:8] != "Prereq: "]
# Out:
# Empty DataFrame
# Columns: [title, prereq, terms, hours, optional, description, instructor, section_head]
# Index: []

# %%
df['prereq'] = df['prereq'].str[8:] #remove "Prereq: " from the start of every entry

# %%
temp= df['title'].str.split(n=1)
df['code']= temp.str.get(0)
df['title']= temp.str.get(1)
del(temp)

df.insert(0, 'code', df.pop('code')) #remove the code column and reinsert it at the beginning
df.head()
# Out:
#      code                                              title  \
# 0  6.100A  Introduction to Computer Science Programming i...
# 1  6.100B  Introduction to Computational Thinking and Dat...
# 2  6.100L   Introduction to Computer Science and Programming
# 3  6.1010                        Fundamentals of Programming
# 4  6.1020                              Software Construction
#
#                                prereq                                  terms  \
# 0                                None   U (Fall, Spring; first half of term)
# 1  6.100A or permission of instructor  U (Fall, Spring; second half of term)
# 2                                None                       U (Fall, Spring)
# 3                              6.100A                       U (Fall, Spring)
# 4                              6.1010                             U (Spring)
#
#                         hours  \
# 0                 2-0-4 units
# 1                 2-0-4 units
# 2                 2-0-4 units
# 3  2-4-6 units. Institute LAB
# 4                3-0-12 units
#
#                                             optional  \
# 0          Credit cannot also be received for 6.100L
# 1  Credit cannot also be received for 9.C20[J] , ...
# 2          Credit cannot also be received for 6.100A
# 3                                               None
# 4                                               None
#
#                                          description  \
# 0  Introduction to computer science and programmi...
# 1  Provides an introduction to using computation ...
# 2  Introduction to computer science and programmi...
# 3  Introduces fundamental concepts of programming...
# 4  Introduces fundamental principles and techniqu...
#
#                                         instructor  \
# 0                                          A. Bell
# 1                            A. Bell, J. V. Guttag
# 2                            A. Bell, J. V. Guttag
# 3  D. S. Boning, A. Chlipala, S. Devadas, A. Hartz
# 4                         M. Goldman, R. C. Miller
#
#                          section_head
# 0  Programming & Software Engineering
# 1  Programming & Software Engineering
# 2  Programming & Software Engineering
# 3  Programming & Software Engineering
# 4  Programming & Software Engineering

# %%
df['terms'].str[0].value_counts()
# Out:
# terms
# U    198
# G    174
# A     34
# Name: count, dtype: int64

# %%
df[df['terms'].str[0] == 'A'].head()
# Out:
#          code                                         title  \
# 13     6.5120               Formal Reasoning About Programs
# 22     6.1420  Fixed Parameter and Fine-grained Computation
# 24  6.5220[J]                         Randomized Algorithms
# 25     6.5230                      Advanced Data Structures
# 26     6.5240                     Sublinear Time Algorithms
#
#                                                prereq  \
# 13                               6.1020 and 6.1200[J]
# 22  6.1200[J] , 6.1210 , and ( 6.1220[J] , 6.1400[...
# 24  ( 6.1200[J] or 6.3700 ) and ( 6.1220[J] or 6.5...
# 25                                          6.1220[J]
# 26              6.1220[J] or permission of instructor
#
#                                                 terms        hours optional  \
# 13  Acad Year 2024-2025: Not offered Acad Year 202...  3-0-9 units     None
# 22  Acad Year 2024-2025: U (Fall) Acad Year 2025-2...  3-0-9 units     None
# 24  Acad Year 2024-2025: G (Spring) Acad Year 2025...  5-0-7 units     None
# 25  Acad Year 2024-2025: G (Spring) Acad Year 2025...  3-0-9 units     None
# 26  Acad Year 2024-2025: G (Fall) Acad Year 2025-2...  3-0-9 units     None
#
#                                           description  \
# 13  Surveys techniques for rigorous mathematical r...
# 22  An overview of the theory of parameterized alg...
# 24  Studies how randomization can be used to make ...
# 25  More advanced and powerful data structures for...
# 26  Sublinear time algorithms understand parameter...
#
#                   instructor                  section_head
# 13               A. Chlipala         Programming Languages
# 22  R. Williams, V. Williams  Theoretical Computer Science
# 24              D. R. Karger  Theoretical Computer Science
# 25             E. D. Demaine  Theoretical Computer Science
# 26              R. Rubinfeld  Theoretical Computer Science

# %%
def GU_extract(term):
    temp=term.split()
    offered_to=[]
    if 'G' in temp:
        offered_to.append('G')
    if 'U' in temp:
        offered_to.append('U')
    if len(offered_to) == 1:
        return offered_to[0]
    else:
        return offered_to
    
df['offered_to']= df['terms'].apply(GU_extract)
display(df['offered_to'].value_counts())
display(df.head())
# Out:
# offered_to
# U    206
# G    200
# Name: count, dtype: int64
#      code                                              title  \
# 0  6.100A  Introduction to Computer Science Programming i...
# 1  6.100B  Introduction to Computational Thinking and Dat...
# 2  6.100L   Introduction to Computer Science and Programming
# 3  6.1010                        Fundamentals of Programming
# 4  6.1020                              Software Construction
#
#                                prereq                                  terms  \
# 0                                None   U (Fall, Spring; first half of term)
# 1  6.100A or permission of instructor  U (Fall, Spring; second half of term)
# 2                                None                       U (Fall, Spring)
# 3                              6.100A                       U (Fall, Spring)
# 4                              6.1010                             U (Spring)
#
#                         hours  \
# 0                 2-0-4 units
# 1                 2-0-4 units
# 2                 2-0-4 units
# 3  2-4-6 units. Institute LAB
# 4                3-0-12 units
#
#                                             optional  \
# 0          Credit cannot also be received for 6.100L
# 1  Credit cannot also be received for 9.C20[J] , ...
# 2          Credit cannot also be received for 6.100A
# 3                                               None
# 4                                               None
#
#                                          description  \
# 0  Introduction to computer science and programmi...
# 1  Provides an introduction to using computation ...
# 2  Introduction to computer science and programmi...
# 3  Introduces fundamental concepts of programming...
# 4  Introduces fundamental principles and techniqu...
#
#                                         instructor  \
# 0                                          A. Bell
# 1                            A. Bell, J. V. Guttag
# 2                            A. Bell, J. V. Guttag
# 3  D. S. Boning, A. Chlipala, S. Devadas, A. Hartz
# 4                         M. Goldman, R. C. Miller
#
#                          section_head offered_to
# 0  Programming & Software Engineering          U
# 1  Programming & Software Engineering          U
# 2  Programming & Software Engineering          U
# 3  Programming & Software Engineering          U
# 4  Programming & Software Engineering          U

# %%
df['prereq']= df['prereq'].replace("None", None) #set prereq string "None" values to actual None values

# %%
#save to csv for future reference
df.to_csv("data/Cleaned_EECE.csv", index=False)
